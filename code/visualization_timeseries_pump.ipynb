# %%
import pandas as pd 

path="../data/combined_data/"

# %%
comb70 = pd.read_csv(path+"combined_csv70.csv",decimal=",",index_col=False)

# %%
comb70.head(1)
# Out:
#    Unnamed: 0          TimeStamp     Value DataQuality  PercentGood  Comments  \
# 0           0  1-1-2018 00:00:05  3604.701        Good        100.0       NaN
#
#    City.PumpType column_idk measurementType
# 0  GBS_DB.RG8170      FT510  Debietmeting.Q

# %%
# %timeit comb70["TimeStamp"]=pd.to_datetime(comb70["TimeStamp"],format='%d-%m-%Y %H:%M:%S')
# Out:
# 21.5 ms ± 611 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
comb70.plot(x="TimeStamp",y="Value",figsize=(25,10),kind="line",linewidth=0.5)
